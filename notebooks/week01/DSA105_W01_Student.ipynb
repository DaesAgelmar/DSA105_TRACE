# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 1 — How Do We Tell a Computer What to Do?
#
# **Part A — Core:** problem → algorithm → Input–Process–Output (IPO) → executable representation
# **Part B — Practice:** sequencing, faded code, debugging, transfer
#
# > **Class rule:** reason first. Python is the executable representation of the reasoning.

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. Precision challenge
#
# Which instruction is more executable?
#
# **A.** “Calculate the total sales.”
# **B.** “Add Monday, Tuesday, and Wednesday sales and store the result as `total_sales`.”
#
# Write one reason why B is more suitable for a computer.

# %% [markdown]
# ### 2. Domain problem — three-day sales
#
# A store records:
#
# - Monday: 1,250 TL
# - Tuesday: 1,480 TL
# - Wednesday: 1,320 TL
#
# Identify:
#
# | Element | Your answer |
# |---|---|
# | Input | |
# | Process | |
# | Output | |

# %% [markdown]
# ### 3. Put the algorithm in order
#
# A. Display the total and average.
# B. Read the three daily sales values.
# C. Start.
# D. Calculate the average as total / 3.
# E. Calculate the total of the three sales values.
# F. End.
#
# Write the correct order before moving on.

# %% [markdown]
# ### 4. First executable representation
#
# Do not memorize Python grammar yet. Read the names as part of the explanation.
#
# Predict `total_sales` and `average_sales` before running.

# %%
monday_sales = 1250
tuesday_sales = 1480
wednesday_sales = 1320

total_sales = monday_sales + tuesday_sales + wednesday_sales
average_sales = total_sales / 3

print("Total sales:", total_sales)
print("Average daily sales:", average_sales)

# %% [markdown]
# Notice the shared Python form already being modeled:
#
# - meaningful lowercase names;
# - multiple words joined with underscores;
# - spaces around operators;
# - one computation per readable line.
#
# You do not need to memorize a style guide. Treat this as normal Python.

# %% [markdown]
# ### 5. Modify
#
# Use:
#
# - Monday: 900
# - Tuesday: 1,100
# - Wednesday: 1,300
#
# Predict first, then complete and run.

# %%
monday_sales = 900
tuesday_sales = 1100
wednesday_sales = 1300

total_sales = ...
average_sales = ...

print("Total sales:", total_sales)
print("Average daily sales:", average_sales)

# %% [markdown]
# ## Part B — Practice and transfer
#
# ### 6. Human CPU challenge
#
# A shop knows the **unit price** and **quantity sold**. Write an algorithm to calculate revenue.
#
# Your partner must follow it literally. If the partner has to guess, revise the instruction.

# %% [markdown]
# ### 7. Faded example
#
# A café sold 42 coffees at 75 TL each.

# %%
unit_price = 75
quantity_sold = 42

revenue = ...

print("Revenue:", ...)

# %% [markdown]
# ### 8. Debug the algorithm, not the syntax
#
# A student wrote:
#
# 1. Display total revenue.
# 2. Read unit price.
# 3. End.
# 4. Read quantity.
# 5. Calculate revenue = unit price × quantity.
# 6. Start.
#
# Rewrite the sequence correctly. Is the defect syntactic or algorithmic?

# %% [markdown]
# ### 9. Independent build — Lab Evidence
#
# A company sold three products today:
#
# - Product A revenue: 2,400 TL
# - Product B revenue: 3,150 TL
# - Product C revenue: 1,950 TL
#
# Do:
#
# 1. IPO.
# 2. A 5–7 step algorithm.
# 3. Predict the total.
# 4. Implement.
# 5. Run and verify.

# %%
product_a_revenue = 2400
product_b_revenue = 3150
product_c_revenue = 1950

# Calculate the total revenue here.
