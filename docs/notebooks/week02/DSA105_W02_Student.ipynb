# %% [markdown]
# # DSA105 TRACE Studio
# ## Week 2 — From Instructions to Executable Code
#
# **Part A — Core:** statements and execution order
# **Part B — Practice:** tracing, ordering, faded code, transfer
#
# The goal is not Python vocabulary for its own sake. The goal is to see how an ordered algorithm becomes executable.

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. Retrieval
#
# Why must `revenue` be calculated after both `unit_price` and `quantity_sold` are known?

# %% [markdown]
# ### 2. Read the sequence before running
#
# Predict the exact output order.

# %%
customer_name = "Ada"
product_name = "Notebook"

print("Customer:", customer_name)
print("Product:", product_name)
print("Order recorded")

# %% [markdown]
# ### 3. Algorithm → code
#
# Algorithm:
#
# 1. Store a unit price.
# 2. Store a quantity.
# 3. Calculate revenue.
# 4. Display revenue.
#
# Read the code and match each statement to one step.

# %%
unit_price = 150
quantity_sold = 27
revenue = unit_price * quantity_sold

print("Revenue:", revenue)

# %% [markdown]
# The names are longer than `x`, `y`, and `z`, but they reduce explanation work. The code should help the reader reconstruct the algorithm.

# %% [markdown]
# ### 4. Order matters
#
# Predict what is wrong before running.

# %%
unit_price = 150
quantity_sold = 27

print("Revenue:", revenue)

revenue = unit_price * quantity_sold

# %% [markdown]
# Explain the failure in terms of execution order, not only the error message.

# %% [markdown]
# ## Part B — Practice and transfer
#
# ### 5. Faded program
#
# Complete the missing statement.

# %%
coffee_unit_price = 75
coffee_quantity = 42

coffee_revenue = ...

print("Coffee revenue:", coffee_revenue)

# %% [markdown]
# ### 6. Reorder the code mentally
#
# Which statements must come first?
#
# ```text
# print("Total:", order_total)
# order_total = item_price * item_quantity
# item_quantity = 6
# item_price = 320
# ```
#
# Write the valid order.

# %% [markdown]
# ### 7. Independent build — Lab Evidence
#
# A delivery service completed:
#
# - 18 standard deliveries at 65 TL;
# - 9 express deliveries at 110 TL.
#
# Build a sequential program that calculates:
#
# - standard revenue;
# - express revenue;
# - total revenue.
#
# Predict the final total before running.

# %%
standard_delivery_price = 65
standard_delivery_count = 18
express_delivery_price = 110
express_delivery_count = 9

# Build the remaining statements here.
