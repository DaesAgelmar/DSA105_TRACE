# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 2 Homework — From Algorithm to Executable Sequence
#
# ### Submission evidence
# Submit your Colab link and short answers through the Week 2 Homework Google Form.
#
# ### Rule
# You may use AI **only after you have produced your own algorithm and prediction**.

# %% [markdown]
# ## Scenario — Small Warehouse Dispatch Report
#
# A warehouse dispatches:
#
# - 14 small packages at 65 TL handling revenue each;
# - 9 large packages at 110 TL handling revenue each.
#
# The manager wants a short program that displays:
#
# 1. a heading;
# 2. small-package revenue;
# 3. large-package revenue;
# 4. total handling revenue;
# 5. a completion message.

# %% [markdown]
# ## Task 1 — Algorithm
#
# Write a precise 6–8 step algorithm before writing Python.
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## Task 2 — Prediction
#
# Before running Python, calculate:
#
# **Predicted small-package revenue:** ...
# **Predicted large-package revenue:** ...
# **Predicted total revenue:** ...

# %% [markdown]
# ## Task 3 — Build the executable representation
#
# Complete the code below.
#
# Do not add unnecessary complexity. The goal is a clear sequential program.

# %%
print("Warehouse Dispatch Report")

print("Small-package revenue:")
print(...)

print("Large-package revenue:")
print(...)

print("Total handling revenue:")
print(...)

print("Report complete")

# %% [markdown]
# ## Task 4 — Verification
#
# After running:
#
# **Actual small-package revenue:** ...
# **Actual large-package revenue:** ...
# **Actual total revenue:** ...
#
# Did your prediction match?
#
# If not, identify whether the problem came from:
#
# - your arithmetic;
# - your algorithm;
# - your code;
# - your execution trace.

# %% [markdown]
# ## Task 5 — Transfer
#
# A second warehouse wants the same report for **three package categories** instead of two.
#
# Without writing full code, explain what must change in:
#
# 1. the algorithm;
# 2. the Python statements;
# 3. the output structure.

# %% [markdown]
# ## Task 6 — AI Use Reflection
#
# Did you use an AI coding assistant?
#
# - [ ] No
# - [ ] Yes — explanation
# - [ ] Yes — debugging
# - [ ] Yes — syntax/code completion
# - [ ] Yes — alternative solution
# - [ ] Yes — full solution generation
#
# If yes:
#
# **What had you already produced before asking AI?**
# ...
#
# **What did AI suggest?**
# ...
#
# **What did you verify, reject, or change?**
# ...
