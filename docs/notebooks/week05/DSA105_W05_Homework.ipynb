# %% [markdown]
# # DSA105 — Week 5 Homework
# ## Programs That Interact
#
# ### Scenario — Delivery charge calculator
#
# Ask the user for:
#
# - customer name;
# - number of packages;
# - charge per package.
#
# Calculate and display the total delivery charge.

# %% [markdown]
# ## Task 1 — IPO design
#
# Write the Input–Process–Output structure before coding.

# %%
# Build the interactive program here.

# %% [markdown]
# ## Task 2 — Type reasoning
#
# For each input, state whether it should remain `str` or be converted to `int` / `float`.

# %% [markdown]
# ## Task 3 — Test cases
#
# Run at least two different cases and record expected vs actual output.

# %% [markdown]
# ## Task 4 — Failure case
#
# What happens if the user types text where your program expects an integer?
#
# Explain what this reveals about input assumptions.

# %% [markdown]
# ## Task 5 — AI reflection
#
# If you used AI, explain what you had already designed before asking it and what you verified afterward.
