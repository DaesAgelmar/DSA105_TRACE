# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 5 — Programs That Interact
#
# **Today's theme:** input, output, conversion, and interactive execution.

# %% [markdown]
# ## Session 1 — Input enters the program
#
# ### Retrieval warm-up
#
# 1. What is an expression?
# 2. What does assignment store?
# 3. Why can `"120"` not always be treated like `120`?
# 4. What does `print()` do?

# %% [markdown]
# ## 1. First interactive program
#
# Predict what happens before running.

# %%
name = input("What is your name? ")
print("Hello,", name)

# %% [markdown]
# ### ACTIVITY 1 — Identify IPO
#
# For this program, identify:
#
# - Input
# - Process
# - Output
#
# Does the program perform a calculation yet?

# %% [markdown]
# ## 2. `input()` returns text
#
# Predict the type of `age_text`.

# %%
age_text = input("Enter your age: ")
print(age_text)
print(type(age_text))

# %% [markdown]
# ### ACTIVITY 2 — Why text?
#
# Explain why Python cannot assume that every user entry should be numeric.

# %% [markdown]
# ## 3. Converting input
#
# If we want to calculate with a whole number:

# %%
quantity = int(input("Enter quantity: "))
print(type(quantity))
print(quantity)

# %% [markdown]
# For decimal values:

# %%
price = float(input("Enter unit price: "))
print(type(price))
print(price)

# %% [markdown]
# ### ACTIVITY 3 — Predict, then run
#
# What happens if the user enters:
#
# - `12` for quantity?
# - `12.5` for quantity?
# - `abc` for quantity?
#
# Do not treat an error as failure. Treat it as evidence about the program's assumptions.

# %% [markdown]
# ## 4. Complete IPO cycle
#
# Build a simple interactive revenue program.

# %%
quantity = int(input("Enter quantity sold: "))
unit_price = float(input("Enter unit price: "))

revenue = quantity * unit_price

print("Revenue:", revenue)

# %% [markdown]
# ### ACTIVITY 4 — Trace
#
# Write the data flow:
#
# user entry → ______ → ______ → expression → ______

# %% [markdown]
# ## Session 2 — Modify, debug, and build
#
# ### 5. Debug the conversion
#
# Why does this produce text repetition rather than numeric multiplication?

# %%
quantity = input("Enter quantity: ")
print(quantity * 3)

# %% [markdown]
# ### ACTIVITY 5 — Repair it
#
# Change only what is necessary.

# %% [markdown]
# ## 6. Pair challenge — Interactive total cost
#
# Create a program that asks for:
#
# - number of items;
# - price per item.
#
# Then prints total cost.

# %%
# Pair challenge here.

# %% [markdown]
# ## 7. Independent Build — Lab Evidence
#
# ### Scenario — Simple consulting invoice
#
# Ask the user for:
#
# - consultant name;
# - hours worked;
# - hourly rate.
#
# Then:
#
# 1. convert numeric inputs appropriately;
# 2. calculate fee;
# 3. print consultant name;
# 4. print hours;
# 5. print hourly rate;
# 6. print total fee.
#
# Before running, predict the result for:
# - 12 hours
# - 850 TL/hour

# %%
# Build your Week 5 lab program here.

# %% [markdown]
# ## 8. Exit reflection
#
# 1. What type does `input()` initially return?
# 2. Why do we convert some inputs?
# 3. What is the difference between `print()` and `input()`?
# 4. Which part was hardest?
# 5. Rate yourself 1–5:
#
# > I can build a small interactive program that receives, converts, processes, and displays data.

# %% [markdown]
# ## Week 5 takeaway
#
# **Prompt → Input → Conversion → Processing → Output → Verification**
