# %% [markdown]
# # DSA105 TRACE Studio
# ## Week 5 — Programs That Interact
#
# **Part A — Core:** input, output, conversion
# **Part B — Practice:** readable interactive programs and conversion debugging

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. `input()` produces text

# %%
customer_name = input("Customer name: ")

print(customer_name)
print(type(customer_name))

# %% [markdown]
# ### 2. Convert before calculating

# %%
quantity = int(input("Quantity: "))
unit_price = float(input("Unit price: "))

total_price = quantity * unit_price

print(f"Total price: {total_price:.2f}")

# %% [markdown]
# Read the program as three blocks:
#
# 1. input and conversion;
# 2. computation;
# 3. output.
#
# The blank lines make that structure visible without adding any new Python rule.

# %% [markdown]
# ### 3. Predict the failure

# %%
quantity_text = input("Quantity: ")

print("Stored type:", type(quantity_text))

# %% [markdown]
# If the user types `12`, why is the stored value still text?

# %% [markdown]
# ## Part B — Practice and transfer
#
# ### 4. Debug This

# %%
distance_km = input("Distance in km: ")
rate_per_km = 15

# Predict why this representation is unsuitable for numeric multiplication.
print(type(distance_km))

# %% [markdown]
# Repair by converting the input at the boundary where it enters the program.

# %% [markdown]
# ### 5. Lab — event registration
#
# Ask the user for:
#
# - number of participants;
# - fee per participant.
#
# Calculate and display the total fee.

# %%
# Input and conversion


# Computation


# Output
