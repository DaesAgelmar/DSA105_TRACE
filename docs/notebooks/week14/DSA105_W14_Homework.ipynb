# %% [markdown]
# # DSA105 · TRACE Portfolio Close — Week 14
#
# Choose one program from Weeks 8–14 and revise it.
#
# Include:
# 1. original problem;
# 2. algorithm;
# 3. final code;
# 4. one bug/weakness;
# 5. test that exposed it;
# 6. corrected version;
# 7. 100–150 word verification reflection.

# %%
# Final revised program

# %% [markdown]
# ## Verification reflection
#
# Write 100–150 words.
