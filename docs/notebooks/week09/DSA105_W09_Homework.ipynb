# %% [markdown]
# # DSA105 · TRACE Homework — Week 9
#
# Build a **2 stores × 5 days** transaction-count program.
#
# Output:
# - each store total;
# - company total;
# - company average per store.
#
# Explain accumulator placement.

# %%
# Build here

# %% [markdown]
# ## Verification
#
# Create one small case where you can compute all totals manually.
