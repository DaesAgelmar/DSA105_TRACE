# %% [markdown]
# # DSA105 TRACE Homework — Week 9
#
# Build a **2 stores × 5 days** transaction-count program.
#
# Output:
#
# - each store total;
# - company total;
# - company average per store.
#
# Use separate names for store-level and company-level state.

# %%
# Build here.

# %% [markdown]
# ## Explain
#
# Why are the two accumulators initialized in different places?
#
# Provide one manually verified store total.
