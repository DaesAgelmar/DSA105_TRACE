# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 3 Homework — Representing Information
#
# ### Submission evidence
# Submit your Colab link and short answers through the Week 3 Homework Google Form.
#
# ### AI rule
# Think first. Produce your own representation choices before asking AI. Verify any AI suggestion.

# %% [markdown]
# ## Scenario — Inventory item record
#
# A small retailer wants to represent one inventory item:
#
# - item code: 5018
# - item name: Wireless Mouse
# - unit price: 749.90 TL
# - units in stock: 26
# - currently available: yes
# - supplier code: "0347"
#
# Notice that the supplier code contains digits but should remain **text**, because it is an identifier rather than a quantity.

# %% [markdown]
# ## Task 1 — Predict the representation
#
# Before writing code, fill in:
#
# | Information | Predicted Python type |
# |---|---|
# | item code | ... |
# | item name | ... |
# | unit price | ... |
# | units in stock | ... |
# | currently available | ... |
# | supplier code | ... |
#
# For one row, explain why the type matters.

# %% [markdown]
# ## Task 2 — Assign clear variable names
#
# Create six variables with meaningful names.
#
# Then print each value.

# %%
# Create the six variables here.

# %% [markdown]
# ## Task 3 — Inspect the types
#
# Use `type()` to verify every variable.
#
# Did every actual type match your prediction?

# %%
# Inspect all six variables here.

# %% [markdown]
# ## Task 4 — Reassignment
#
# The retailer sells 4 units.
#
# For this week's scope, do **not** calculate the new stock with an expression.
#
# Instead, reassign `units_in_stock` directly from `26` to `22`.
#
# Then display the new value.
#
# Explain:
#
# > What did reassignment change?

# %%
# Reassign and print here.

# %% [markdown]
# ## Task 5 — Representation reasoning
#
# Explain why this would be a poor representation for the supplier code:
#
# ```python
# supplier_code = 347
# ```
#
# What information could be lost compared with:
#
# ```python
# supplier_code = "0347"
# ```

# %% [markdown]
# ## Task 6 — Transfer
#
# A university wants to represent one course record:
#
# - course code: "DSA105"
# - course title: "Fundamentals of Algorithms and Programming"
# - ECTS: 5
# - compulsory: yes
# - average weekly lab hours: 2.0
#
# Without writing full code, specify an appropriate Python type for each value and justify one non-obvious choice.

# %% [markdown]
# ## Task 7 — AI Use Reflection
#
# Did you use an AI assistant?
#
# - [ ] No
# - [ ] Yes — explanation
# - [ ] Yes — debugging
# - [ ] Yes — syntax/code completion
# - [ ] Yes — alternative representation
# - [ ] Yes — full solution generation
#
# If yes:
#
# **What had you already decided before asking AI?**
# ...
#
# **What did AI suggest?**
# ...
#
# **What did you verify, reject, or change?**
# ...
