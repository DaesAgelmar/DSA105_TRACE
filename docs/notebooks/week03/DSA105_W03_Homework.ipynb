# %% [markdown]
# # DSA105 TRACE Homework — Week 3
#
# Represent a university course using variables for:
#
# - course code;
# - course title;
# - ECTS;
# - average grade;
# - whether the course is compulsory.
#
# Choose each type deliberately.

# %%
# Create the variables here using descriptive snake_case names.

# %% [markdown]
# ## Explain
#
# For each variable, explain why its representation is appropriate.
#
# Include one example where converting a code to a number would lose meaning.
