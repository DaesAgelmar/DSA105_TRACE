# %% [markdown]
# # DSA105 TRACE Studio
# ## Week 3 — How Does a Computer Represent Information?
#
# **Part A — Core:** values, variables, types, assignment
# **Part B — Practice:** naming, reassignment, representation mismatches
#
# This is the week where Python naming becomes explicit: ordinary variable names use descriptive `snake_case`.

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. Value vs name
#
# Read this as: the name `customer_count` refers to the integer value `25`.

# %%
customer_count = 25

print(customer_count)
print(type(customer_count))

# %% [markdown]
# ### 2. Different representations

# %%
order_count = 12
unit_price = 79.5
customer_name = "Mert"
is_member = True

print(type(order_count))
print(type(unit_price))
print(type(customer_name))
print(type(is_member))

# %% [markdown]
# ### 3. Same-looking content, different type
#
# Predict both types before running.

# %%
supplier_code = "0347"
supplier_number = 347

print(supplier_code, type(supplier_code))
print(supplier_number, type(supplier_number))

# %% [markdown]
# Why should a code such as `"0347"` often remain text rather than become an integer?

# %% [markdown]
# ### 4. Assignment and reassignment

# %%
available_seats = 25
print("Before:", available_seats)

available_seats = 18
print("After:", available_seats)

# %% [markdown]
# Trace the name and value after each assignment.

# %% [markdown]
# ## Part B — Python naming as part of meaning
#
# Prefer:

# %%
course_name = "Algorithms"
weekly_hours = 3
is_compulsory = True

# %% [markdown]
# Avoid names such as `cn`, `wh`, or `x1` when the domain meaning matters.
#
# Boolean names often read naturally with prefixes such as `is_`, `has_`, or `can_`.

# %% [markdown]
# ### 5. Debug the representation

# %%
quantity = "12"
unit_price = 80

print(quantity, type(quantity))
print(unit_price, type(unit_price))

# %% [markdown]
# Without using operators beyond what you already know, explain why the representation of `quantity` may become a problem later.

# %% [markdown]
# ### 6. Independent build — Lab Evidence
#
# Represent the following customer record:
#
# - customer name;
# - age;
# - account balance;
# - whether the customer is active.
#
# Use meaningful `snake_case` names and inspect each type.

# %%
# Build the four variables and inspect their types.
