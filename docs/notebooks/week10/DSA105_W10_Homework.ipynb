# %% [markdown]
# # DSA105 · TRACE Homework — Week 10
#
# Create:
#
# ```python
# def delivery_cost(distance_km, rate_per_km):
#     ...
# ```
#
# Return the cost. Test at least three cases, including distance `0`.

# %%
# Your function

# %% [markdown]
# ## Test table
#
# Record input, predicted output, actual output, and result.
