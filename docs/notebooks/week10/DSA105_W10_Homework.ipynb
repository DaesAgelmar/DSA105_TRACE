# %% [markdown]
# # DSA105 TRACE Homework — Week 10
#
# Create:
#
# ```python
# def calculate_delivery_cost(distance_km, rate_per_km):
#     """Return delivery cost from distance and rate."""
#     ...
# ```
#
# Requirements:
#
# - return the result;
# - do not print inside the function;
# - test at least three cases;
# - include `distance_km = 0`.

# %%
def calculate_delivery_cost(distance_km, rate_per_km):
    """Return delivery cost from distance and rate."""
    # Complete.
    ...

# %% [markdown]
# ## Test evidence
#
# For each case record:
#
# - input;
# - predicted output;
# - actual output;
# - whether they match.
