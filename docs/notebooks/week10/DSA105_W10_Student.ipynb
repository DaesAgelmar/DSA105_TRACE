# %% [markdown]
# # DSA105 · TRACE Studio
# ## Week 10 — Breaking Problems into Reusable Pieces
#
# **Part A — Core:** functions, parameters, return values
# **Part B — Practice & Verification:** contracts, tests, AI Verify

# %% [markdown]
# ## 1. First function

# %%
def calculate_revenue(quantity, unit_price):
    revenue = quantity * unit_price
    return revenue

print(calculate_revenue(12, 50))

# %% [markdown]
# ## 2. Parameters and arguments
#
# Change each argument separately. What remains the same about the function?

# %% [markdown]
# ## 3. Return vs print

# %%
def calculate_profit(revenue, cost):
    return revenue - cost

profit = calculate_profit(5000, 3200)
print(profit)

# %% [markdown]
# ## 4. Debug This

# %%
def calculate_area(width, height):
    area = width * 10
    return area

# %% [markdown]
# ## 5. AI Verify

# %%
def apply_tax(price, tax_rate=0.18):
    final_price = price * 1.18
    return final_price

print(apply_tax(200, 0.08))

# %% [markdown]
# Expected: `216.0`.
#
# Explain what the parameter promises and why the body violates that promise.

# %%
# Corrected version

# %% [markdown]
# ## 6. Lab — Three-function business calculation

# %%
# calculate_revenue
# calculate_profit
# profit_margin
