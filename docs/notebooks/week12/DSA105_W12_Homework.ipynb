# %% [markdown]
# # DSA105 TRACE Homework — Week 12
#
# Read `transactions.txt` containing one amount per line.
#
# Write `summary.txt` containing:
#
# - transaction count;
# - total;
# - average.
#
# Keep file I/O separate from reusable transformations where practical.

# %%
def clean_lines(lines):
    """Return stripped, non-empty lines."""
    # Complete.
    ...


def parse_amounts(lines):
    """Return floating-point amounts parsed from text lines."""
    # Complete.
    ...


# File input


# Transformation


# Summary


# File output

# %% [markdown]
# ## Reflection
#
# Why is text cleaning part of correctness rather than merely formatting?
