# %% [markdown]
# # DSA105 · TRACE Homework — Week 12
#
# Read `transactions.txt` containing one numeric amount per line.
#
# Write `summary.txt` containing:
# - count;
# - total;
# - average.
#
# Use `with open(...)`.

# %%
# Build here

# %% [markdown]
# ## Reflection
#
# Why is file cleaning part of program correctness?
