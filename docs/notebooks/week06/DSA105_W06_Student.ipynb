# %% [markdown]
# # DSA105 TRACE Studio
# ## Week 6 — Programs That Make Decisions
#
# **Part A — Core:** Boolean conditions and branches
# **Part B — Practice:** branch order, boundary cases, domain rules

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. Comparisons produce Boolean values

# %%
order_total = 1250
free_delivery_threshold = 2000

is_free_delivery = order_total >= free_delivery_threshold

print(is_free_delivery)
print(type(is_free_delivery))

# %% [markdown]
# The name `is_free_delivery` reads as a yes/no proposition. This is a normal way to name Boolean state.

# %% [markdown]
# ### 2. Basic branch

# %%
order_total = 1250
free_delivery_threshold = 2000

if order_total >= free_delivery_threshold:
    delivery_message = "Free delivery"
else:
    delivery_message = "Standard delivery"

print(delivery_message)

# %% [markdown]
# ### 3. Multi-branch rule

# %%
order_total = 1500

if order_total >= 2000:
    delivery_message = "Free delivery"
elif order_total >= 1000:
    delivery_message = "Reduced delivery"
else:
    delivery_message = "Standard delivery"

print(delivery_message)

# %% [markdown]
# ### 4. Boundary tests
#
# Predict the branch for:
#
# - 999.99
# - 1000
# - 1999.99
# - 2000

# %% [markdown]
# ## Part B — Practice and transfer
#
# ### 5. Debug branch order

# %%
order_total = 2500

if order_total >= 1000:
    delivery_message = "Reduced delivery"
elif order_total >= 2000:
    delivery_message = "Free delivery"
else:
    delivery_message = "Standard delivery"

print(delivery_message)

# %% [markdown]
# Why can the `>= 2000` branch never be reached? Repair the order.

# %% [markdown]
# ### 6. Lab — delivery policy
#
# Implement:
#
# - below 1000 → Standard
# - 1000 to below 2000 → Reduced
# - 2000 and above → Free
#
# Use a descriptive result name and verify all four boundary cases.

# %%
order_total = 0  # Change this value for each test.

# Write the branching logic here.
