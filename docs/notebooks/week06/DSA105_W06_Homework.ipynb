# %% [markdown]
# # DSA105 — Week 6 Homework
# ## Programs That Make Decisions
#
# ### Scenario — Membership fee rule
#
# Ask the user for age.
#
# Rules:
#
# - under 18 → 120 TL
# - 18–64 → 240 TL
# - 65 or above → 150 TL

# %% [markdown]
# ## Task 1 — Decision design
#
# Write the rule in ordinary language before coding.

# %%
# Build the program here.

# %% [markdown]
# ## Task 2 — Test cases
#
# Use at least:
#
# - 17
# - 18
# - 64
# - 65
#
# Predict before running.

# %% [markdown]
# ## Task 3 — Branch order
#
# Explain why the order of conditions matters in your solution.

# %% [markdown]
# ## Task 4 — Debugging
#
# Create one intentionally incorrect branch order, explain the error, then repair it.

# %% [markdown]
# ## Task 5 — AI reflection
#
# If AI was used, identify one suggestion you verified rather than accepting automatically.
