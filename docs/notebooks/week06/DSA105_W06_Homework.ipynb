# %% [markdown]
# # DSA105 TRACE Homework — Week 6
#
# Implement a ticket-pricing rule:
#
# - under 18 → 120 TL
# - 18 through 64 → 240 TL
# - 65 and above → 150 TL
#
# Use a descriptive variable for the final ticket price.

# %%
age = 0  # Replace during testing.

# Decision logic


# Output

# %% [markdown]
# ## Required boundary tests
#
# Test ages:
#
# - 17
# - 18
# - 64
# - 65
#
# Predict each price before running.
