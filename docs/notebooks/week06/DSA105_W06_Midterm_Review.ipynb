# %% [markdown]
# # DSA105 — Short Midterm Review
# ## Weeks 1–6
#
# This notebook introduces no new content.
#
# Use the same shared Python form used throughout the course:
# - meaningful `snake_case` names;
# - readable expressions;
# - explicit conversion;
# - clear branch structure.

# %% [markdown]
# ## 1. Algorithm → representation
#
# Scenario: 12 items at 85 TL each.
#
# Write IPO and predict the output.

# %%
quantity_sold = 12
unit_price = 85

total_revenue = quantity_sold * unit_price

print("Total revenue:", total_revenue)

# %% [markdown]
# ## 2. Representation
#
# Predict the types.

# %%
course_code = "DSA105"
student_count = 42
average_grade = 78.5
is_compulsory = True

print(type(course_code))
print(type(student_count))
print(type(average_grade))
print(type(is_compulsory))

# %% [markdown]
# ## 3. Expression debugging

# %%
first_value = 1200
second_value = 1500
third_value = 1800

incorrect_average = first_value + second_value + third_value / 3
print(incorrect_average)

# %% [markdown]
# Repair the grouping and explain the error.

# %% [markdown]
# ## 4. Input and conversion
#
# What type does `input()` return? Where should conversion occur?

# %%
quantity = int(input("Quantity: "))
unit_price = float(input("Unit price: "))

total_price = quantity * unit_price

print(f"Total price: {total_price:.2f}")

# %% [markdown]
# ## 5. Conditional boundaries

# %%
order_total = 2000

if order_total >= 2000:
    delivery_message = "Free delivery"
elif order_total >= 1000:
    delivery_message = "Reduced delivery"
else:
    delivery_message = "Standard delivery"

print(delivery_message)

# %% [markdown]
# Test mentally: `999.99`, `1000`, `1999.99`, `2000`.
#
# Explain why branch order matters.
