# %% [markdown]
# # DSA105 — Midterm Review
# ## Weeks 1–6 · Short Consolidation
#
# This review belongs to **Week 6**.
#
# Week 7 is the physical in-class midterm examination.
#
# No new programming concept is introduced here.

# %% [markdown]
# ## 1. Problem → Algorithm → Program
#
# A shop wants to calculate total revenue from two product categories.
#
# Write:
#
# 1. Input
# 2. Process
# 3. Output
# 4. A 5–7 step algorithm
#
# Then explain the difference between the algorithm and its Python representation.

# %% [markdown]
# ## 2. Representation and tracing
#
# Predict before running:

# %%
product = "Notebook"
quantity = 12
unit_price = 85.50
available = True

print(type(product))
print(type(quantity))
print(type(unit_price))
print(type(available))

# %% [markdown]
# Explain why each value uses that representation.

# %% [markdown]
# ## 3. Expressions and debugging
#
# The intended average is the mean of three sales values.
#
# Repair the expression:

# %%
day1 = 1200
day2 = 1500
day3 = 1800

average = day1 + day2 + day3 / 3
print(average)

# %% [markdown]
# ## 4. Input and conversion
#
# Design a program that asks for quantity and unit price, then prints total cost.
#
# Before coding, state which input needs `int()` and which needs `float()`.

# %%
# Practice here.

# %% [markdown]
# ## 5. Decision logic and boundaries
#
# A customer receives:
#
# - Free shipping at 2000 TL or above;
# - Standard shipping below 2000 TL.
#
# Write the decision and test:
#
# - 1999.99
# - 2000
# - 2500

# %%
# Practice here.

# %% [markdown]
# ## 6. Final self-check
#
# Without notes, can you:
#
# - explain IPO;
# - distinguish value, variable, and type;
# - trace assignment;
# - build a numeric expression;
# - convert user input;
# - write and trace an `if/else`;
# - identify a boundary case;
# - explain one debugging decision?
#
# If one item is uncertain, review that week's TRACE module before the exam.
