# %% [markdown]
# # DSA105 · TRACE Homework — Week 8
#
# Build a 7-day production tracker.
#
# Your notebook must show:
# 1. algorithm;
# 2. prediction;
# 3. loop;
# 4. accumulator;
# 5. total and average;
# 6. verification.

# %% [markdown]
# ## Algorithm
#
# Write your steps before coding.

# %% [markdown]
# ## Prediction
#
# Choose seven production values and calculate the expected total by hand.

# %%
# Build your program here

# %% [markdown]
# ## Verification
#
# Record predicted output, actual output, and whether they match.
