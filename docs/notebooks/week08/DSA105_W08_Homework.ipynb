# %% [markdown]
# # DSA105 TRACE Homework — Week 8
#
# Build a **7-day production tracker**.
#
# Required:
#
# 1. algorithm;
# 2. prediction;
# 3. loop;
# 4. accumulator;
# 5. total and average;
# 6. verification.
#
# Use `day` for the loop counter if you display the day number. Use `_` only if the counter is intentionally unused.

# %% [markdown]
# ## Algorithm and prediction
#
# Choose seven production values and compute the expected total by hand.

# %%
# Build your program here.

# %% [markdown]
# ## Verification
#
# Record predicted output, actual output, and whether they match.
