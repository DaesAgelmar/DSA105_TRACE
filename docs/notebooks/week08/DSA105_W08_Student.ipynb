# %% [markdown]
# # DSA105 · TRACE Studio
# ## Week 8 — Making Computers Repeat Work
#
# **Part A — Core:** loops, `range()`, counters, accumulators
# **Part B — Practice & Verification:** debugging, AI Verify, domain application
#
# **Rule:** predict first; run second.

# %% [markdown]
# ## 1. Predict a simple loop
#
# Before running, write the exact output.

# %%
for i in range(1, 5):
    print(i)

# %% [markdown]
# ## 2. Accumulator
#
# Predict the final value of `total`.

# %%
total = 0

for value in range(1, 5):
    total += value

print(total)

# %% [markdown]
# ## 3. Daily sales
#
# Enter four values. Before running, state how many times the body should execute.

# %%
total = 0

for day in range(1, 5):
    sale = float(input("Enter daily sales: "))
    total += sale

print("Four-day total:", total)
print("Average:", total / 4)

# %% [markdown]
# ## 4. Modify
#
# Change the program to collect **six** hourly customer counts and calculate the average.

# %%
# Your code here

# %% [markdown]
# ## 5. Debug This
#
# This program says it collects five days but asks for only four. Diagnose before fixing.

# %%
total = 0
for day in range(1, 5):
    sale = float(input("Sale: "))
    total += sale
print(total)

# %% [markdown]
# ## 6. AI Verify
#
# An AI assistant wrote:

# %%
total = 0

for day in range(1, 4):
    sale = float(input("Enter daily sales: "))
    total += sale

print("Four-day total:", total)

# %% [markdown]
# Use intended inputs: `120, 95, 130, 80`. Correct total: `425`.
#
# 1. Predict how many values the code will actually request.
# 2. Run.
# 3. Diagnose the logic error.
# 4. Fix and verify with a second four-day case.

# %%
# Corrected version

# %% [markdown]
# ## 7. Lab build — Five-day expense tracker
#
# Requirements:
# - ask for 5 expenses;
# - total;
# - average;
# - one hand-computed test case.

# %%
# Build here
