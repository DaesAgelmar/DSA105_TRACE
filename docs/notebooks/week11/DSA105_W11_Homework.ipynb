# %% [markdown]
# # DSA105 · TRACE Homework — Week 11
#
# Inventory list task:
# - start with five stock counts;
# - append one;
# - total units;
# - build a new list of counts below a reorder threshold;
# - explain why filtering into a new list is safer than removing during iteration.

# %%
# Build here
