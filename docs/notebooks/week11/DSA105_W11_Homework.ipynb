# %% [markdown]
# # DSA105 TRACE Homework — Week 11
#
# Inventory task:
#
# - start with five stock counts;
# - append a sixth;
# - calculate total units;
# - create a **new list** of counts below a reorder threshold;
# - explain why you did not remove values from the original list during iteration.

# %%
stock_counts = [18, 4, 11, 2, 25]

# Append one count, calculate total, and build reorder_counts.
