# %% [markdown]
# # DSA105 · TRACE Homework — Week 13
#
# Build a robust unit-price calculator.
#
# Requirements:
# - quantity input;
# - unit-price input;
# - targeted exception handling;
# - total when valid;
# - three tests;
# - explanation: “does not crash” ≠ “correctly handles errors”.

# %%
# Build here
