# %% [markdown]
# # DSA105 TRACE Homework — Week 13
#
# Build a robust unit-price calculator.
#
# Requirements:
#
# - request quantity and unit price;
# - catch expected numeric conversion failures specifically;
# - calculate total when inputs are valid;
# - use three tests;
# - explain why “does not crash” is not the same as “correctly handles errors.”

# %%
# Build here.

# %% [markdown]
# ## Test evidence
#
# Include:
#
# - a valid integer/float case;
# - invalid numeric text;
# - one boundary or unusual valid case.
