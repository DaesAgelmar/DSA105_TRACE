# %% [markdown]
# # DSA105 — Week 4 Homework
# ## Turning Data into New Information
#
# ### Scenario — Event ticket revenue
#
# An event sold:
#
# - 85 standard tickets at 350 TL;
# - 24 premium tickets at 650 TL.
#
# You will transform the raw values into revenue measures.

# %% [markdown]
# ## Task 1 — Predict
#
# Before coding, calculate:
#
# - standard-ticket revenue;
# - premium-ticket revenue;
# - total revenue;
# - premium revenue share of total revenue.

# %%
# Store the four raw values here.

# %% [markdown]
# ## Task 2 — Build expressions
#
# Create variables for:
#
# - `standard_revenue`
# - `premium_revenue`
# - `total_revenue`
# - `premium_share`
#
# Print each result.

# %%
# Write your expressions here.

# %% [markdown]
# ## Task 3 — Parentheses
#
# Explain whether parentheses are necessary in each expression and whether adding them would improve readability.

# %% [markdown]
# ## Task 4 — Debugging
#
# The intended average ticket price is:
#
# > total revenue / total number of tickets
#
# Repair this incorrect expression:
#
# ```python
# average_price = standard_revenue + premium_revenue / 85 + 24
# ```

# %%
# Correct the expression here.

# %% [markdown]
# ## Task 5 — AI reflection
#
# If you used AI, state:
#
# - what you predicted first;
# - what AI suggested;
# - what you verified or changed.
