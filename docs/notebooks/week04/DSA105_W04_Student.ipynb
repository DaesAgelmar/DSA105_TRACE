# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 4 — Turning Data into New Information
#
# **Today's theme:** Operators, expressions, evaluation order, and transformation.
#
# > **Class cycle:** Predict → Run → Modify → Explain → Build → Test

# %% [markdown]
# ## Session 1 — From represented values to computed values
#
# ### Retrieval warm-up
#
# 1. What is a variable name?
# 2. What is the difference between `120` and `"120"`?
# 3. What does reassignment change?
# 4. What does `type()` tell us?

# %% [markdown]
# ## 1. Today's problem — From sales data to business information
#
# A shop records:
#
# - units sold: 18
# - unit price: 240 TL
#
# The raw values are useful, but the manager wants a new value:
#
# > **revenue**
#
# Before running code, calculate the revenue yourself.

# %%
units_sold = 18
unit_price = 240

revenue = units_sold * unit_price

print(revenue)

# %% [markdown]
# ### ACTIVITY 1 — Name the parts
#
# In:
#
# ```python
# revenue = units_sold * unit_price
# ```
#
# identify:
#
# - variable receiving the result;
# - operands;
# - operator;
# - complete expression.

# %% [markdown]
# ## 2. Arithmetic operators
#
# Common operators:
#
# | Operator | Meaning |
# |---|---|
# | `+` | addition |
# | `-` | subtraction |
# | `*` | multiplication |
# | `/` | division |
# | `//` | floor division |
# | `%` | remainder |
# | `**` | exponentiation |
#
# This week, focus first on choosing the operator that matches the problem.

# %% [markdown]
# ### ACTIVITY 2 — Predict before running
#
# Predict all four results.

# %%
a = 17
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)

# %% [markdown]
# ## 3. Expressions create new information
#
# A variable may receive the result of an expression.

# %%
gross_revenue = 5200
cost = 3100

profit = gross_revenue - cost
profit_margin = profit / gross_revenue

print(profit)
print(profit_margin)

# %% [markdown]
# ### ACTIVITY 3 — Trace
#
# Before running, complete:
#
# - `profit` = ...
# - `profit_margin` = ...
#
# Then explain which line **creates** new information rather than merely storing raw input.

# %% [markdown]
# ## 4. Parentheses and evaluation order
#
# Compare:
#
# ```python
# 10 + 5 * 2
# ```
#
# and:
#
# ```python
# (10 + 5) * 2
# ```
#
# Predict both results.

# %%
print(10 + 5 * 2)
print((10 + 5) * 2)

# %% [markdown]
# ### ACTIVITY 4 — Explain
#
# Why do these two expressions produce different results?
#
# Write one rule:
#
# > Parentheses are useful when...

# %% [markdown]
# ## Session 2 — Modify, debug, and build
#
# ### 5. Domain transformation
#
# A business has:
#
# - base salary: 32000
# - monthly bonus: 4500
#
# Build an expression for total monthly compensation.

# %%
base_salary = 32000
monthly_bonus = 4500

# Create total_compensation below.

# %% [markdown]
# ## 6. Debug the formula
#
# A store calculates average daily sales for three days.
#
# The intended formula is:
#
# > sum of three days divided by 3
#
# But the code is:

# %%
day1 = 1200
day2 = 1500
day3 = 1800

average_sales = day1 + day2 + day3 / 3
print(average_sales)

# %% [markdown]
# ### ACTIVITY 5 — Repair and explain
#
# 1. Predict the incorrect output logic.
# 2. Correct the expression.
# 3. Explain why parentheses matter.

# %% [markdown]
# ## 7. Independent Build — Lab Evidence
#
# ### Scenario — Subscription revenue
#
# A software service has:
#
# - 125 basic users paying 90 TL;
# - 48 pro users paying 220 TL.
#
# Build a program that:
#
# 1. stores the four input values;
# 2. calculates basic-plan revenue;
# 3. calculates pro-plan revenue;
# 4. calculates total revenue;
# 5. calculates the share of total revenue coming from the pro plan;
# 6. prints all four results.
#
# Predict every calculated value before running.

# %%
# Build your Week 4 lab program here.

# %% [markdown]
# ## 8. Exit reflection
#
# 1. What is an expression?
# 2. Why is `revenue = units * price` different from simply writing two raw values?
# 3. What role do parentheses play?
# 4. Which part was hardest?
# 5. Rate yourself 1–5:
#
# > I can translate a simple quantitative relationship into a Python expression.

# %% [markdown]
# ## Week 4 takeaway
#
# **Raw values → Expression → Evaluation → New information → Verification**
