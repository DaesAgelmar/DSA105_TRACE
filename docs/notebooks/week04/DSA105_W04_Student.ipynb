# %% [markdown]
# # DSA105 TRACE Studio
# ## Week 4 — Turning Data into New Information
#
# **Part A — Core:** operators and expressions
# **Part B — Practice:** readable formulas, precedence, debugging, transfer
#
# Expressions should make the domain relationship visible.

# %% [markdown]
# ## Part A — Core understanding
#
# ### 1. Revenue

# %%
quantity_sold = 36
unit_price = 120

revenue = quantity_sold * unit_price

print("Revenue:", revenue)

# %% [markdown]
# ### 2. Profit and margin
#
# Predict both values before running.

# %%
revenue = 5200
cost = 3100

profit = revenue - cost
profit_margin = profit / revenue

print("Profit:", profit)
print("Profit margin:", profit_margin)

# %% [markdown]
# ### 3. Parentheses communicate intent
#
# Predict both expressions.

# %%
first_result = 10 + 5 * 2
second_result = (10 + 5) * 2

print(first_result)
print(second_result)

# %% [markdown]
# Parentheses are not only for fixing precedence. They can make the intended relationship easier to read.

# %% [markdown]
# ## Part B — Practice and transfer
#
# ### 4. Debug the formula
#
# A student wants the average of `1200`, `1500`, and `1800`:

# %%
monday_sales = 1200
tuesday_sales = 1500
wednesday_sales = 1800

incorrect_average = monday_sales + tuesday_sales + wednesday_sales / 3

print("Average:", incorrect_average)

# %% [markdown]
# Diagnose the relationship error and rewrite the expression so the grouping is explicit.

# %%
correct_average = ...

# %% [markdown]
# ### 5. Lab — product revenue mix
#
# A store sold:
#
# - Standard: 75 units × 150 TL
# - Pro: 48 units × 220 TL
#
# Calculate:
#
# - standard revenue;
# - pro revenue;
# - total revenue;
# - pro revenue share.
#
# Use names that make every expression self-explanatory.

# %%
standard_quantity = 75
standard_unit_price = 150
pro_quantity = 48
pro_unit_price = 220

# Build the remaining expressions here.
