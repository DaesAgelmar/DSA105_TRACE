# %% [markdown]
# # DSA105 — Fundamentals of Algorithms and Programming
# ## Week 1 Homework — From Problem to Executable Representation
#
# ### Submission evidence
# Submit your Colab link and short answers through the Week 1 Homework Google Form.
#
# ### Rule
# You may use AI **only after you have produced your own IPO description and algorithm draft**.

# %% [markdown]
# ## Scenario — Daily Delivery Revenue
#
# A delivery service completed three delivery batches:
#
# - Morning revenue: 1,875 TL
# - Afternoon revenue: 2,460 TL
# - Evening revenue: 1,665 TL
#
# The manager wants:
# 1. total daily revenue;
# 2. average revenue per batch.
#
# ### Task 1 — IPO
# Write:
#
# **Input:** ...
# **Process:** ...
# **Output:** ...

# %% [markdown]
# ## Task 2 — Algorithm
#
# Write a precise 6–8 step algorithm.
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## Task 3 — Prediction
#
# Before running Python:
#
# **Predicted total:** ...
# **Predicted average:** ...

# %%
morning_revenue = 1875
afternoon_revenue = 2460
evening_revenue = 1665

# Complete the solution below.
total_revenue = ...
average_revenue = ...

print("Total revenue:", total_revenue)
print("Average revenue:", average_revenue)

# %% [markdown]
# ## Task 4 — Verification
#
# After running:
#
# **Actual total:** ...
# **Actual average:** ...
#
# Did your prediction match?
# If not, identify the reasoning error.

# %% [markdown]
# ## Task 5 — Transfer
#
# A different business records **four** sales periods instead of three.
#
# Without writing full code, explain what must change in:
# 1. the **input**;
# 2. the **process**;
# 3. the calculation of the **average**.

# %% [markdown]
# ## Task 6 — AI Use Reflection
#
# Did you use an AI coding assistant?
#
# - [ ] No
# - [ ] Yes — explanation
# - [ ] Yes — debugging
# - [ ] Yes — syntax/code completion
# - [ ] Yes — alternative solution
# - [ ] Yes — full solution generation
#
# If yes:
#
# **What had you already produced before asking AI?**
# ...
#
# **What did you accept, reject, or change in the AI response?**
# ...
